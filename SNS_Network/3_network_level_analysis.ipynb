# %%
library(igraph)

# %%
library("IRdisplay")
display_png(file="C:/Users/joyh1/Desktop/빅데이터_20-1/img.jpg")

# %%
# 상호호혜성
# 10개의 노드로 링크는 랜덤으로 가상 네트워크 설정
rgraph(10) # 왜안되지..?;;
# Out:
# Error in rgraph(10): 함수 "rgraph"를 찾을 수 없습니다
# Traceback:
